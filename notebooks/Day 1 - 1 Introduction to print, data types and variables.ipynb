# %% [markdown]
# # Markdown
#
# I can write _any_ __text__ and ´format´ it how I like!
# * Bullet points
#     * could be
#         * not more useful
# or even $\LaTeX$ or whole formulas $$f(x) = 3*x$$

# %% [markdown]
# # Coding is like math

# %% [markdown]
# ## The print function
#
# The `print` function can be executed by just writing `print()`.
#
# Try to print __0__, __5.2__, __"hello world!"__

# %% [markdown]
# ## Data types in Python
# You can check the data type by using the function `type()`.
#
# You have two different main number types: __integers__ and __floats__.
# Try to figure out the data type of these examples:
# * 0
# * -5
# * 0.0
# * 1.234
# * 1e5
# * 0+5j

# %% [markdown]
# You can convert numbers using the `int()` and `float()` function!

# %% [markdown]
# We also can use text in the form of __strings__ (indicated by single _'_ and double _"_ quotes)

# %% [markdown]
# You can also convert between numbers and strings (__parsing__)

# %% [markdown]
# __Boolean__ values (_True_ and _False_)

# %% [markdown]
# You can gain __boolean__ values via __comparison__
# * Is equal: `==`
# * Is not equal: `!=`
# * Bigger / smaller than `>` or `<`
# * Bigger or equal to / smaller or equal to `>=` and `<=`
# * Something `in` something else

# %% [markdown]
# ## Operations on numbers and strings

# %% [markdown]
# Basically, normal maths apply
# ```
#     +   (add)
#     -   (substract)
#     /   (divide)
#     *   (multiply)
# ```
# Special notation:
# ```
#     //  (floor division)
#     **  (exponent)
#     %   (modulo)
# ```

# %% [markdown]
# Mathematical operations are executed in a specific order (as you're used to it...)
#
# ![Order of execution of math operations](math_operations2.png)

# %% [markdown]
# Working with strings...

# %% [markdown]
# Add dynamic information into a string using `{}`
# `:.2f` gives e.g. the first two digits of the precision

# %% [markdown]
# But what you can do....

# %% [markdown]
# _______________________
# ### TASKS
#
# * A) What kind of data type is created when you divide integers, especially 5 by 5 and 5 by 2?
# * B) Is 5 and 5.0 the same? Try to compare the values and check the boolean result. Try to compare the type as well.
# * C) How do you easily create the string "pypypypypypypypypypypython"?
# * D) What mathematical combination of 2, 3, 4 and 5 results in __-14__?
#
# _______________________

# %% [markdown]
# ## Storing data types in variables
#
# Please use variable names that have a "speaking name":

# %% [markdown]
# Operations are still valid

# %% [markdown]
# And you can store the result in the same or in a different variable

# %% [markdown]
# You may use short variable names, if they are temporary or have a specific meaning in the community. For example, ```i``` is typically the variable name for an interator/counter.

# %% [markdown]
# What is the __type__ of `a`?

# %% [markdown]
# Swapping variables

# %%
a = 5
b = 2

# %% [markdown]
# ## Working more on strings
#
# This is the GFP open-reading frame.

# %%
gfp = "..."

# %% [markdown]
# Can we calculate the GC content here?
#
# $$ gccontent = \frac{Gs+Cs}{As + Ts + Gs + Cs} \cdot 100\%$$

# %% [markdown]
# More string possibilities:

# %% [markdown]
# How to access parts of a `str`?
#
#              0  1  2  3
#         s = "A  B  C  D"   (ignore any spaces please)
#             -4 -3 -2 -1

# %%
s = "ABCDEFGHIJK"

# %% [markdown]
# Slicing with square brackets `[ start : stop : step]`

# %% [markdown]
# ______________
# ### TASKS
# * A) Calculate the AT content of the GFP ORF!
# * B) Store the complement strand of GFP in a variable called gfp_complement. Tip: Use the replace function!
#
#
#         ATGC
#         ||||
#         TACG
#
# * C) Get the first and last 10 bases of the GFP ORF and skip every second base!
